# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
# Read image.
location_circles = []
#im1 = cv2.imread('D:\Sissi_Lange\Master\Vorlesungen\F&E\F-E_Projekt_Montage\images\\templates\P_top_3.png', cv2.IMREAD_UNCHANGED)
im1 = cv2.imread('D:\Sissi_Lange\Master\Vorlesungen\F&E\F-E_Projekt_Montage\images\\real_pics\IMG20221110152408.jpg', cv2.IMREAD_UNCHANGED)
im1 = cv2.resize(im1, (1000,1000))
plt.imshow(im1)
plt.show()
im = cv2.cvtColor(im1 ,cv2.COLOR_BGR2RGB)
plt.imshow(im)
plt.show()

alpha = 1.5 # Contrast control
beta = 1 # Brightness control
adjusted = cv2.convertScaleAbs(im, alpha=alpha, beta=beta)
plt.imshow(adjusted)
plt.show()

gray = cv2.cvtColor(adjusted ,cv2.COLOR_BGR2GRAY)
  
# Blur using 3 * 3 kernel.
gray_blurred = cv2.blur(gray, (1, 1))
plt.imshow(gray_blurred)
plt.show()



# _, binary = cv2.threshold(adjusted, 130, 130, cv2.THRESH_BINARY_INV)
# plt.imshow(binary, cmap="gray")
# plt.show()

# gray_blurred = cv2.blur(binary, (1, 1))
# plt.imshow(gray_blurred)
# plt.show()


#rows= gray_blurred.shape[0]
#Apply Hough transform on the blurred image.
detected_circles = cv2.HoughCircles(gray, 
                   cv2.HOUGH_GRADIENT, 1, 20, param1 = 50,
               param2 = 30, minRadius = 8, maxRadius = 25)
  
# Draw circles that are detected.
if detected_circles is not None:
  
    # Convert the circle parameters a, b and r to integers.
    detected_circles = np.uint16(np.around(detected_circles))
  
    for pt in detected_circles[0, :]:
        a, b, r = pt[0], pt[1], pt[2]
        location_circles.append([a, b])
  
        # Draw the circumference of the circle.
        cv2.circle(im1, (a, b), r, (0, 255, 0), 10)
  
        # Draw a small circle (of radius 1) to show the center.
        #cv2.circle(im, (a, b), 1, (0, 0, 255), 3)
        print(a , "", b)
imS = cv2.resize(im1, (960, 540))     
cv2.imshow("Detected Circle", imS)
  
cv2.waitKey(0)
# Out:
# 180  704
# 180  366
# 54  444
# 600  138
# 682  952
# 122  32
# 402  24
# 188  34
# 666  182
# 884  848
# 674  78
# 882  594
# 468  76
# 946  584
# 958  954
# 536  78
# 942  82
# 56  136
# 180  760
# 392  752
# 894  794
# 826  484
# 470  742
# 530  30
# 608  958
# 690  750
# 932  182
# 194  960
# 612  746
# 120  950
# 402  76
# 800  74
# 822  900
# 876  482
# 946  326
# 468  26
# 180  542
# 680  840
# 878  22
# 124  390
# 824  430
# 50  88
# 56  640
# 58  30
# 334  180
# 468  852
# 682  904
# 872  120
# 942  224
# 180  650
# 56  902
# 122  896
# 186  426
# 326  904
# 334  26
# 400  180
# 540  760
# 608  258
# 324  86
# 884  692
# 886  740
# 184  480
# 252  28
# 262  960
# 398  130
# 596  88
# 672  128
# 746  850
# 886  532
# 892  954
# 944  276
# 60  184
# 180  314
# 196  180
# 324  756
# 538  954
# 876  428
# 472  896
# 952  528
# 192  794
# 54  852
# 818  316
# 58  798
# 262  132
# 124  748
# 178  588
# 266  904
# 824  850
# 958  794
# 124  238
# 122  84
# 124  136
# 192  846
# 748  904
# 806  126
# 878  168
# 682  268
# 122  496
# 750  274
# 740  184
# 822  378
# 738  30
# 54  958
# 128  288
# 262  184
# 806  174
# 538  852
# 730  130
# 884  646
# 952  426
# 616  416
# 876  378
# 876  68
# 944  118
# 190  908
# 126  328
# 466  184
# 330  128
# 468  130
# 256  270
# 266  852
# 536  904
# 386  534
# 602  32
# 872  222
# 536  132
# 892  898
# 332  794
# 250  748
# 58  744
# 198  130
# 56  494
# 182  272
# 878  332
# 958  740
# 58  328
# 52  598
# 186  228
# 324  274
# 470  960
# 824  528
# 392  588
# 548  586
# 56  238
# 308  360
# 262  224
# 740  222
# 616  528
# 190  84
# 822  258
# 832  756
# 944  480
# 542  356
# 390  414
# 616  644
# 402  228
# 124  846
# 746  796
# 332  854
# 400  854
# 734  80
# 958  846
# 124  434
# 806  28
# 604  180
# 758  750
# 58  382
# 124  586
# 616  358
# 614  896
# 622  590
# 466  358
# 460  414
# 754  956
# 124  188
# 386  472
# 548  412
# 822  586
# 822  960
# 464  650
# 394  272
# 624  470
# 698  592
# 694  412
# 698  358
# 116  692
# 694  528
# 696  474
# 394  646
# 462  270
# 470  228
# 312  476
# 404  956
# 540  646
# 402  904
# 830  700
# 336  228
# 390  356
# 960  900
# 820  796
# 808  284
# 674  24
# 308  588
# 464  592
# 862  182
# 700  648
# 400  796
# 334  964
# 678  790
# 830  644
# 812  230
# 536  174
# 668  224
# 614  848
# 614  796
# 126  642
# 310  534
# 538  270
# 876  916
# 474  796
# 540  536
# 878  278
# 266  76
# 60  284
# 50  694
# 946  28
# 308  646
# 464  536
# 124  794
# 308  418
# 950  374
# 958  636
# 120  538
# 182  334
# 696  114
# -1

# %%
len(location_circles)
# Out:
# 235

# %%
# Python code to sort the lists using the second element of sublists
# Inplace way to sort, use of third variable
def Sort_2(sub_li):
    l = len(sub_li)
    for i in range(0, l):
        for j in range(0, l-i-1):
            if (sub_li[j][1] > sub_li[j + 1][1]):
                tempo = sub_li[j]
                sub_li[j]= sub_li[j + 1]
                sub_li[j + 1]= tempo
    return sub_li

def Sort_1(sub_li):
    l = len(sub_li)
    for i in range(0, l):
        for j in range(0, l-i-1):
            if (sub_li[j][0] > sub_li[j + 1][0]):
                tempo = sub_li[j]
                sub_li[j]= sub_li[j + 1]
                sub_li[j + 1]= tempo
    return sub_li
  
# Driver Code
sub_li =[['rishav', 10], ['akash', 5], ['ram', 20], ['gaurav', 15]]
print(len(Sort_2(location_circles)))
# Out:
# 95

# %%
location_circles = Sort_2(location_circles)
print(location_circles)
# Out:
# [[398, 72], [1026, 72], [308, 72], [936, 72], [486, 72], [578, 72], [848, 72], [220, 72], [756, 72], [576, 160], [754, 160], [220, 162], [668, 162], [398, 162], [848, 162], [308, 162], [1028, 162], [488, 162], [936, 164], [308, 250], [1028, 250], [488, 250], [216, 250], [756, 250], [578, 252], [400, 252], [936, 252], [668, 252], [846, 254], [668, 338], [1026, 340], [938, 340], [486, 340], [754, 340], [218, 342], [308, 342], [848, 342], [578, 342], [400, 342], [936, 428], [220, 428], [488, 428], [758, 430], [398, 430], [1026, 430], [310, 430], [848, 432], [308, 518], [396, 518], [1026, 520], [936, 520], [758, 520], [488, 520], [218, 520], [850, 522], [936, 608], [1024, 608], [220, 610], [488, 610], [668, 610], [398, 610], [576, 610], [310, 610], [758, 612], [848, 612], [310, 696], [936, 698], [486, 698], [664, 698], [220, 700], [758, 700], [398, 700], [576, 700], [1028, 700], [848, 700], [936, 786], [308, 786], [756, 788], [578, 788], [668, 788], [846, 788], [220, 790], [398, 790], [488, 790], [1028, 790], [488, 876], [666, 876], [220, 878], [758, 878], [1026, 878], [308, 880], [848, 880], [400, 880], [578, 880], [938, 880]]

# %%
old_height = location_circles[0][1]
grids = []
row = []
min_height = location_circles[0][1]
max_height = location_circles[-1][1]
gap = (max_height-min_height)*0.05

for i in range(len(location_circles)):
        height = location_circles[i][1]
        if (height-old_height) < (gap*1.4):
            row.append(location_circles[i])
        else:
            row = Sort_1(row)
            space = get_space(row)
            row = check_row(row, space)
            grids.append(row)
            row = []
            row.append(location_circles[i])
            old_height = height
        if i == (len(location_circles)-1):
            row = Sort_1(row)
            space = get_space(row)
            row = check_row(row, space)
            grids.append(row)
            row = []
            row.append(location_circles[i])
            old_height = height
            break

print(grids)
print(len(grids))
# Out:
# [[[220, 72], [308, 72], [398, 72], [486, 72], [578, 72], [701.4, 72], [756, 72], [848, 72], [936, 72], [1026, 72]], [[220, 162], [308, 162], [398, 162], [488, 162], [576, 160], [668, 162], [754, 160], [848, 162], [936, 164], [1028, 162]], [[216, 250], [308, 250], [400, 252], [488, 250], [578, 252], [668, 252], [756, 250], [846, 254], [936, 252], [1028, 250]], [[218, 342], [308, 342], [400, 342], [486, 340], [578, 342], [668, 338], [754, 340], [848, 342], [938, 340], [1026, 340]], [[220, 428], [310, 430], [398, 430], [488, 428], [606.9, 428], [731.745, 428], [758, 430], [848, 432], [936, 428], [1026, 430]], [[218, 520], [308, 518], [396, 518], [488, 520], [606.9, 520], [731.745, 520], [758, 520], [850, 522], [936, 520], [1026, 520]], [[220, 610], [310, 610], [398, 610], [488, 610], [576, 610], [668, 610], [758, 612], [848, 612], [936, 608], [1024, 608]], [[220, 700], [310, 696], [398, 700], [486, 698], [576, 700], [664, 698], [758, 700], [848, 700], [936, 698], [1028, 700]], [[220, 790], [308, 786], [398, 790], [488, 790], [578, 788], [668, 788], [756, 788], [846, 788], [936, 786], [1028, 790]], [[220, 878], [308, 880], [400, 880], [488, 876], [578, 880], [666, 876], [758, 878], [848, 880], [938, 880], [1026, 878]]]
# 10

# %%
def get_space(row):
    distances = []
    for i in range(len(row)):
        if i == (len(row)-1):
            break
        distance = row[i+1][0] - row[i][0]
        distances.append(distance)
    min(distances)
    return distance

# %%
def check_row(row, space):
    for i in range(len(row)):
        if i == (len(row)-1):
            break
        if row[i+1][0]-row[i][0] > (space*1.5):
            new_point = [(row[i][0]+space)*1.05, row[i][1]]
            row.insert(i+1, new_point)
    return row

# %%
length = len(grids[0])
for row in grids:
    print(len(row))
    if length == len(row):
        length = len(row)
print(grids)
# Out:
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# [[[220, 72], [308, 72], [398, 72], [486, 72], [578, 72], [701.4, 72], [756, 72], [848, 72], [936, 72], [1026, 72]], [[220, 162], [308, 162], [398, 162], [488, 162], [576, 160], [668, 162], [754, 160], [848, 162], [936, 164], [1028, 162]], [[216, 250], [308, 250], [400, 252], [488, 250], [578, 252], [668, 252], [756, 250], [846, 254], [936, 252], [1028, 250]], [[218, 342], [308, 342], [400, 342], [486, 340], [578, 342], [668, 338], [754, 340], [848, 342], [938, 340], [1026, 340]], [[220, 428], [310, 430], [398, 430], [488, 428], [606.9, 428], [731.745, 428], [758, 430], [848, 432], [936, 428], [1026, 430]], [[218, 520], [308, 518], [396, 518], [488, 520], [606.9, 520], [731.745, 520], [758, 520], [850, 522], [936, 520], [1026, 520]], [[220, 610], [310, 610], [398, 610], [488, 610], [576, 610], [668, 610], [758, 612], [848, 612], [936, 608], [1024, 608]], [[220, 700], [310, 696], [398, 700], [486, 698], [576, 700], [664, 698], [758, 700], [848, 700], [936, 698], [1028, 700]], [[220, 790], [308, 786], [398, 790], [488, 790], [578, 788], [668, 788], [756, 788], [846, 788], [936, 786], [1028, 790]], [[220, 878], [308, 880], [400, 880], [488, 876], [578, 880], [666, 876], [758, 878], [848, 880], [938, 880], [1026, 878]]]

# %%
print(len(grids), len(grids[0]))
# Out:
# 10 10

# %%
plt.imshow(im)
plt.show()
print(len(im))
print(len(im[0]))
# Out:
# 960
# 1280

# %%
def closest(colors,color):
    colors = np.array(colors)
    color = np.array(color)    
    distances = np.sqrt(np.sum((colors-color)**2,axis=1))    
    index_of_smallest = np.where(distances==np.amin(distances))
    smallest_distance = colors[index_of_smallest]
    return smallest_distance

# %%
import webcolors
from collections import Counter
def get_avarege_color(point, im):
    
    colors = []
    colors_name =[]
    list_of_colors = [[0,0,255],[0,0,0],[255,255,255],[0,255,0],[255,0,0],[255,255,0]]
    for i in range(5):
        for z in range(5):
            color = im[round(point[1]+i), round(point[0]+z)]
            colors.append(color)
            color = im[round(point[1]-i), round(point[0]-z)]
            colors.append(color)
    
    for i in range(len(colors)):         
        closest_color = closest(list_of_colors,colors[i])        
        colors_name.append(webcolors.rgb_to_name((closest_color[0][0],  closest_color[0][1],  closest_color[0][2])))
    data = Counter(colors_name)    
    return data.most_common(1)[0][0]

# %%
import numpy as np
import webcolors

color_name_grid = []

for row in grids:    
    color_name_row = []
    for point in row:        
        color = get_avarege_color(point, im)        
        color_name_row.append(color)        
    color_name_grid.append(color_name_row)

for i in range(len(color_name_grid)):
    print(color_name_grid[i])
# Out:
# ['blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue']
# ['blue', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'blue']
# ['blue', 'red', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'red', 'blue']
# ['blue', 'red', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'red', 'blue']
# ['blue', 'red', 'yellow', 'yellow', 'black', 'yellow', 'yellow', 'yellow', 'red', 'blue']
# ['blue', 'red', 'yellow', 'yellow', 'black', 'yellow', 'yellow', 'yellow', 'red', 'blue']
# ['blue', 'red', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'red', 'blue']
# ['blue', 'red', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'red', 'blue']
# ['blue', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'blue']
# ['blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue']

# %%
import numpy as np
def get_similarity(picture_grid, plan_grid):
    row_pic= len(picture_grid)
    column_pic = len(picture_grid[0])

    row_plan = len(plan_grid)
    column_plan = len(plan_grid[0])

    row_diff = row_pic - row_plan +1
    column_diff = column_pic  - column_plan +1

    
    comp_list = []
    
    for row_comp in range(row_diff):
        for column_comp in range(column_diff):
            number_of_same_colors = 0

            for i in range(len(plan_grid)):
                for z in range(len(plan_grid[0])):
                    plan_color = plan_grid[i][z]
                    pic_color = picture_grid[i+row_comp][z+column_comp]
                    if plan_color == pic_color:
                        number_of_same_colors +=1
            
            comp_list.append(number_of_same_colors)
    max_index = np.argmax(comp_list)
    max_similarity = comp_list[max_index]
    total_pixel = len(plan_grid) * len(plan_grid[0])
    similarity = (max_similarity/total_pixel)*100
    return similarity

# %%
similarity = get_similarity(color_name_grid, color_name_grid)
print(similarity)
# Out:
# 100.0
