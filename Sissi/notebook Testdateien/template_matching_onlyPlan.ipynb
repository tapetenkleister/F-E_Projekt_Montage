# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
img = cv.imread('/home/sissi/workspace/F&E/Test/Bild.png',0)
img2 = img.copy()
template = cv.imread('/home/sissi/workspace/F&E/Test/Plan1.png',0)
w, h = template.shape[::-1]
# All the 6 methods for comparison in a list
methods = ['cv.TM_CCOEFF', 'cv.TM_CCOEFF_NORMED', 'cv.TM_CCORR',
            'cv.TM_CCORR_NORMED', 'cv.TM_SQDIFF', 'cv.TM_SQDIFF_NORMED']
for meth in methods:
    img = img2.copy()
    method = eval(meth)
    # Apply template Matching
    res = cv.matchTemplate(img,template,method)
    
    min_val, max_val, min_loc, max_loc = cv.minMaxLoc(res)

    print(min_val, max_val, min_loc, max_loc)
    # If the method is TM_SQDIFF or TM_SQDIFF_NORMED, take minimum
    if method in [cv.TM_SQDIFF, cv.TM_SQDIFF_NORMED]:
        top_left = min_loc
    else:
        top_left = max_loc
    bottom_right = (top_left[0] + w, top_left[1] + h)
    cv.rectangle(img,top_left, bottom_right, 255, 2)
    plt.subplot(121),plt.imshow(res,cmap = 'gray')
    plt.title('Matching Result'), plt.xticks([]), plt.yticks([])
    plt.subplot(122),plt.imshow(img,cmap = 'gray')
    plt.title('Detected Point'), plt.xticks([]), plt.yticks([])
    plt.suptitle(meth)
    plt.show()
# Out:
# -1010386560.0 -500959936.0 (142, 209) (519, 95)
# -0.4917241036891937 -0.24553681910037994 (364, 209) (519, 97)
# 6856041984.0 9489148928.0 (322, 66) (0, 209)
# 0.7076550126075745 0.7805434465408325 (175, 185) (519, 88)
# 4933957632.0 6874918400.0 (271, 90) (36, 209)
# 0.5223409533500671 0.6163629293441772 (519, 84) (148, 209)

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
img = cv.imread('/home/sissi/workspace/F&E/Test/Bild.png',0)
img2 = img.copy()
template = cv.imread('/home/sissi/workspace/F&E/Test/Plan2.png',0)
w, h = template.shape[::-1]
# All the 6 methods for comparison in a list
methods = ['cv.TM_CCOEFF', 'cv.TM_CCOEFF_NORMED', 'cv.TM_CCORR',
            'cv.TM_CCORR_NORMED', 'cv.TM_SQDIFF', 'cv.TM_SQDIFF_NORMED']
for meth in methods:
    img = img2.copy()
    method = eval(meth)
    # Apply template Matching
    res = cv.matchTemplate(img,template,method)
    
    min_val, max_val, min_loc, max_loc = cv.minMaxLoc(res)

    print(min_val, max_val, min_loc, max_loc)
    # If the method is TM_SQDIFF or TM_SQDIFF_NORMED, take minimum
    if method in [cv.TM_SQDIFF, cv.TM_SQDIFF_NORMED]:
        top_left = min_loc
    else:
        top_left = max_loc
    bottom_right = (top_left[0] + w, top_left[1] + h)
    cv.rectangle(img,top_left, bottom_right, 255, 5)
    plt.subplot(121),plt.imshow(res,cmap = 'gray')
    plt.title('Matching Result'), plt.xticks([]), plt.yticks([])
    plt.subplot(122),plt.imshow(img,cmap = 'gray')
    plt.title('Detected Point'), plt.xticks([]), plt.yticks([])
    plt.suptitle(meth)
    plt.show()
# Out:
# -188523856.0 87332656.0 (493, 295) (340, 183)
# -0.43119457364082336 0.5597315430641174 (432, 256) (340, 183)
# 2418483456.0 5297594368.0 (341, 175) (0, 372)
# 0.8275671005249023 0.97254878282547 (435, 302) (340, 183)
# 165527952.0 4555135488.0 (340, 183) (0, 372)
# 0.06601154804229736 0.7760976552963257 (340, 183) (0, 372)

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
img = cv.imread('/home/sissi/workspace/F&E/Test/Bild.png',0)
img2 = img.copy()
template = cv.imread('/home/sissi/workspace/F&E/Test/Plan3.png',0)
w, h = template.shape[::-1]
# All the 6 methods for comparison in a list
methods = ['cv.TM_CCOEFF', 'cv.TM_CCOEFF_NORMED', 'cv.TM_CCORR',
            'cv.TM_CCORR_NORMED', 'cv.TM_SQDIFF', 'cv.TM_SQDIFF_NORMED']
for meth in methods:
    img = img2.copy()
    method = eval(meth)
    # Apply template Matching
    res = cv.matchTemplate(img,template,method)
    
    min_val, max_val, min_loc, max_loc = cv.minMaxLoc(res)

    print(min_val, max_val, min_loc, max_loc)
    # If the method is TM_SQDIFF or TM_SQDIFF_NORMED, take minimum
    if method in [cv.TM_SQDIFF, cv.TM_SQDIFF_NORMED]:
        top_left = min_loc
    else:
        top_left = max_loc
    bottom_right = (top_left[0] + w, top_left[1] + h)
    cv.rectangle(img,top_left, bottom_right, 255, 2)
    plt.subplot(121),plt.imshow(res,cmap = 'gray')
    plt.title('Matching Result'), plt.xticks([]), plt.yticks([])
    plt.subplot(122),plt.imshow(img,cmap = 'gray')
    plt.title('Detected Point'), plt.xticks([]), plt.yticks([])
    plt.suptitle(meth)
    plt.show()
# Out:
# -199143408.0 159916496.0 (459, 62) (341, 182)
# -0.44899699091911316 0.997816801071167 (460, 69) (341, 182)
# 2264490496.0 4865235968.0 (343, 197) (0, 383)
# 0.8155761957168579 0.9996688961982727 (455, 301) (341, 182)
# 5641554.0 4838133760.0 (341, 182) (0, 383)
# 0.0024430197663605213 0.8939546942710876 (341, 182) (0, 383)

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
img = cv.imread('/home/sissi/workspace/F&E/Test/Bild.png',0)
img2 = img.copy()
template = cv.imread('/home/sissi/workspace/F&E/Test/Plan4.png',0)
w, h = template.shape[::-1]
# All the 6 methods for comparison in a list
methods = ['cv.TM_CCOEFF', 'cv.TM_CCOEFF_NORMED', 'cv.TM_CCORR',
            'cv.TM_CCORR_NORMED', 'cv.TM_SQDIFF', 'cv.TM_SQDIFF_NORMED']
for meth in methods:
    img = img2.copy()
    method = eval(meth)
    # Apply template Matching
    res = cv.matchTemplate(img,template,method)
    
    min_val, max_val, min_loc, max_loc = cv.minMaxLoc(res)

    print(min_val, max_val, min_loc, max_loc)
    # If the method is TM_SQDIFF or TM_SQDIFF_NORMED, take minimum
    if method in [cv.TM_SQDIFF, cv.TM_SQDIFF_NORMED]:
        top_left = min_loc
    else:
        top_left = max_loc
    bottom_right = (top_left[0] + w, top_left[1] + h)
    cv.rectangle(img,top_left, bottom_right, 255, 2)
    plt.subplot(121),plt.imshow(res,cmap = 'gray')
    plt.title('Matching Result'), plt.xticks([]), plt.yticks([])
    plt.subplot(122),plt.imshow(img,cmap = 'gray')
    plt.title('Detected Point'), plt.xticks([]), plt.yticks([])
    plt.suptitle(meth)
    plt.show()
# Out:
# -479977120.0 142587904.0 (526, 355) (347, 176)
# -0.4496654272079468 0.43693313002586365 (526, 0) (347, 176)
# 2669431296.0 5746949632.0 (341, 177) (0, 363)
# 0.7297763824462891 0.9175134301185608 (525, 342) (347, 176)
# 693902400.0 4741344256.0 (347, 176) (0, 363)
# 0.2368953973054886 0.7174345850944519 (347, 176) (557, 363)

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
img = cv.imread('/home/sissi/workspace/F&E/Test/Bild.png',0)
img2 = img.copy()
template = cv.imread('/home/sissi/workspace/F&E/Test/Plan5.png',0)
w, h = template.shape[::-1]
# All the 6 methods for comparison in a list
methods = ['cv.TM_CCOEFF', 'cv.TM_CCOEFF_NORMED', 'cv.TM_CCORR',
            'cv.TM_CCORR_NORMED', 'cv.TM_SQDIFF', 'cv.TM_SQDIFF_NORMED']
for meth in methods:
    img = img2.copy()
    method = eval(meth)
    # Apply template Matching
    res = cv.matchTemplate(img,template,method)
    
    min_val, max_val, min_loc, max_loc = cv.minMaxLoc(res)

    print(min_val, max_val, min_loc, max_loc)
    # If the method is TM_SQDIFF or TM_SQDIFF_NORMED, take minimum
    if method in [cv.TM_SQDIFF, cv.TM_SQDIFF_NORMED]:
        top_left = min_loc
    else:
        top_left = max_loc
    bottom_right = (top_left[0] + w, top_left[1] + h)
    cv.rectangle(img,top_left, bottom_right, 255, 2)
    plt.subplot(121),plt.imshow(res,cmap = 'gray')
    plt.title('Matching Result'), plt.xticks([]), plt.yticks([])
    plt.subplot(122),plt.imshow(img,cmap = 'gray')
    plt.title('Detected Point'), plt.xticks([]), plt.yticks([])
    plt.suptitle(meth)
    plt.show()
# Out:
# -305824448.0 175852400.0 (520, 351) (341, 178)
# -0.379851371049881 0.7111552953720093 (519, 11) (341, 178)
# 2517640960.0 5291889664.0 (341, 172) (0, 367)
# 0.7753957509994507 0.9645669460296631 (487, 297) (341, 178)
# 242275888.0 4903572992.0 (341, 178) (0, 367)
# 0.09242390096187592 0.7986235618591309 (341, 178) (682, 367)
