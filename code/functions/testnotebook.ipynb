# %% [markdown]
# # Test of functions individually

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from display_lego_pattern import display_lego_pattern
from extract_green_plate import extract_green_plate
from detect_circles import detect_circles
from take_image import take_image
from extract_plate import extract_plate

# %% [markdown]
# # Display pattern

# %%
display_lego_pattern([[0, 4, 2],
                       [2, 3, 3],
                       [1, 1, 1]])

# %% [markdown]
# # Extract green plate roughly

# %%
image = cv2.imread('/home/steve/Vorlesungen/FE_Projekt/F-E_Projekt_Montage/code/Pyramide_3.jpg')

result = extract_green_plate(image, correct_rotation=False, debug=False) #deubg doesnt work in jupiter notebook
rotated = extract_green_plate(image, correct_rotation=True, debug=False)

f = plt.figure(figsize=(10,10))
f.add_subplot(1,2, 1)
plt.imshow(result)
f.add_subplot(1,2, 2)
plt.imshow(rotated)
plt.show(block=True)

# %% [markdown]
# # Detect cricles in cropped image

# %%
circles,result_image = detect_circles(result,type_of_image='photo',debug=False)
circles,rot_image = detect_circles(rotated,type_of_image='photo',debug=False)
f = plt.figure(figsize=(15,15))
f.add_subplot(1,2, 1)
plt.imshow(result_image)
f.add_subplot(1,2, 2)
plt.imshow(rot_image)
plt.show(block=True)
# Out:
# Full plate has 572 circles. (24x24 - 4 edge circles)
# circles found: 568
# Full plate has 572 circles. (24x24 - 4 edge circles)
# circles found: 568

# %% [markdown]
# # Take an image with IDS camera
# (needs to be connected and drivers need to be installed)

# %%
low = take_image(exposure_ms=5)

f = plt.figure(figsize=(15,15))
f.add_subplot(1,2, 1)
plt.imshow(low)
high = take_image(exposure_ms=35)
f.add_subplot(1,2, 2)
plt.imshow(high)
plt.show(block=True)
# Out:
# is_InitCamera ERROR
# is_GetCameraInfo ERROR
# is_GetSensorInfo ERROR
# is_ResetToDefault ERROR
# else
# is_AOI ERROR
# is_SetExposure ERROR
# is_AllocImageMem ERROR
# is_CaptureVideo ERROR
# is_InquireImageMem ERROR
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 low = take_image(exposure_ms=5)
#       3 f = plt.figure(figsize=(15,15))
#       4 f.add_subplot(1,2, 1)
#
# File ~/Vorlesungen/FE_Projekt/F-E_Projekt_Montage/code/functions/take_image.py:198, in take_image(exposure_ms, debug)
#     191 ueye.is_WaitEvent(hCam, ueye.IS_SET_EVENT_WB_FINISHED, 100)
#     192 #---------------------------------------------------------------------------------------------------------------------------------------
#     193
#     194
#     195 # In order to display the image in an OpenCV window we need to...
#     196 # ...extract the data of our image memory
# --> 198 array = ueye.get_data(pcImageMemory, width, height, nBitsPerPixel, pitch, copy=False)
#     201 # ...reshape it in an numpy array...
#     202 frame = np.reshape(array,(height.value, width.value, bytes_per_pixel))
#
# File ~/.local/lib/python3.8/site-packages/pyueye/ueye.py:93, in get_data(image_mem, x, y, bits, pitch, copy)
#      91     data = numpy.frombuffer(mem, dtype = numpy.uint8) if numpy else mem
#      92 else:
# ---> 93     data = numpy.ctypeslib.as_array(ctypes.cast(image_mem, ctypes.POINTER(ctypes.c_ubyte)), (y * pitch, )) if numpy else image_mem
#      95 return data
#
# File ~/.local/lib/python3.8/site-packages/numpy/ctypeslib.py:524, in as_array(obj, shape)
#     520         raise TypeError(
#     521             'as_array() requires a shape argument when called on a '
#     522             'pointer')
#     523     p_arr_type = ctypes.POINTER(_ctype_ndarray(obj._type_, shape))
# --> 524     obj = ctypes.cast(obj, p_arr_type).contents
#     526 return asarray(obj)
#
# ValueError: NULL pointer access

# %% [markdown]
# # Extract a rectangle plane which is marked with 4 aruco tags

# %%
image = cv2.imread('/home/steve/Vorlesungen/FE_Projekt/F-E_Projekt_Montage/20230223_124925.jpg')

low = image

f = plt.figure(figsize=(15,15))
f.add_subplot(1,2, 1)
plt.imshow(low)

high = extract_plate(image)
f.add_subplot(1,2, 2)
plt.imshow(high)
plt.show(block=True)

# %% [markdown]
# Tryout for every image taken

# %%
# import the modules
import os
from os import listdir
 
# get the path or directory
folder_dir = "/home/steve/Vorlesungen/FE_Projekt/F-E_Projekt_Montage/photos/test"
for images in os.listdir(folder_dir):
 
    # check if the image ends with png or jpg or jpeg
    if (images.endswith(".png") or images.endswith(".jpg")\
        or images.endswith(".jpeg")):
        # display
        print(images)
    image = cv2.imread(folder_dir+'/'+images)
    plt.imshow(extract_plate(image))
# Out:
# pyramide3.jpg
# pyramide5.jpg
# bridge1.jpg
# castle2.jpg
# castle6.jpg
# castle3.jpg
# castle4.jpg
# castle1.jpg
# pyramide4.jpg
# pyramide3_5.jpg
# castle5.jpg
# pyramide2.jpg
# pyramide1.jpg
# bridge3.jpg
# bridge4.jpg
# bridge2.jpg
