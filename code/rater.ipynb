# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
# Read image.
location_circles = []
#im1 = cv2.imread('D:\Sissi_Lange\Master\Vorlesungen\F&E\F-E_Projekt_Montage\images\\templates\P_top_3.png', cv2.IMREAD_UNCHANGED)
im1 = cv2.imread('/home/steve/Vorlesungen/FE_Projekt/F-E_Projekt_Montage/code/Pyramide_3.jpg', cv2.IMREAD_UNCHANGED)
#im1 = cv2.resize(im1, (1000,1000))
plt.imshow(im1)
plt.show()
im = cv2.cvtColor(im1 ,cv2.COLOR_BGR2RGB)
plt.imshow(im)
plt.show()

alpha = 1.5 # Contrast control
beta = 1 # Brightness control
adjusted = cv2.convertScaleAbs(im, alpha=alpha, beta=beta)
plt.imshow(adjusted)
plt.show()

gray = cv2.cvtColor(adjusted ,cv2.COLOR_BGR2GRAY)
  
# Blur using 3 * 3 kernel.
gray_blurred = cv2.blur(gray, (1, 1))
plt.imshow(gray_blurred)
plt.show()



# _, binary = cv2.threshold(adjusted, 130, 130, cv2.THRESH_BINARY_INV)
# plt.imshow(binary, cmap="gray")
# plt.show()

# gray_blurred = cv2.blur(binary, (1, 1))
# plt.imshow(gray_blurred)
# plt.show()


#rows= gray_blurred.shape[0]
#Apply Hough transform on the blurred image.
detected_circles = cv2.HoughCircles(gray, 
                   cv2.HOUGH_GRADIENT, 1, 20, param1 = 50,
               param2 = 30, minRadius = 8, maxRadius = 25)
  
# Draw circles that are detected.
if detected_circles is not None:
  
    # Convert the circle parameters a, b and r to integers.
    detected_circles = np.uint16(np.around(detected_circles))
  
    for pt in detected_circles[0, :]:
        a, b, r = pt[0], pt[1], pt[2]
        location_circles.append([a, b])
  
        # Draw the circumference of the circle.
        cv2.circle(im1, (a, b), r, (0, 255, 0), 10)
  
        # Draw a small circle (of radius 1) to show the center.
        #cv2.circle(im, (a, b), 1, (0, 0, 255), 3)
        print(a , "", b)
imS = cv2.resize(im1, (960, 540))     
cv2.imshow("Detected Circle", imS)
  
cv2.waitKey(0)
# Out:
# 1172  852
# 1008  890
# 1130  892
# 1172  896
# 1174  730
# 1170  810
# 1048  890
# 1020  728
# 888  764
# 888  888
# 1214  850
# 894  924
# 1018  568
# 1134  608
# 1382  492
# 1216  730
# 890  642
# 964  642
# 374  604
# 890  602
# 1174  648
# 1016  1162
# 972  606
# 966  888
# 1172  770
# 868  528
# 924  642
# 1214  892
# 1300  772
# 1010  604
# 1376  854
# 1540  736
# 1258  810
# 1500  694
# 1176  608
# 1042  848
# 932  606
# 1494  1096
# 1046  686
# 1132  930
# 1054  930
# 1542  696
# 784  960
# 964  684
# 860  1038
# 900  960
# 890  806
# 1212  932
# 1058  568
# 1096  1046
# 974  1160
# 1010  928
# 1534  1098
# 1216  608
# 938  1040
# 972  926
# 1414  972
# 1378  892
# 858  766
# 1128  728
# 1176  968
# 1098  568
# 890  724
# 920  846
# 1092  930
# 1422  694
# 978  1042
# 1340  692
# 824  842
# 1002  808
# 1128  768
# 854  924
# 1178  690
# 1088  892
# 858  684
# 892  684
# 854  844
# 898  564
# 1002  848
# 626  956
# 1084  810
# 924  684
# 888  844
# 928  890
# 1258  732
# 664  1076
# 934  926
# 1256  850
# 856  804
# 922  726
# 1254  1052
# 860  606
# 1212  810
# 1334  1092
# 938  964
# 1136  1006
# 1128  852
# 858  566
# 964  766
# 1136  568
# 1298  812
# 1458  894
# 1126  810
# 113
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
len(location_circles)
# Out:
# 235

# %%
# Python code to sort the lists using the second element of sublists
# Inplace way to sort, use of third variable
def Sort_2(sub_li):
    l = len(sub_li)
    for i in range(0, l):
        for j in range(0, l-i-1):
            if (sub_li[j][1] > sub_li[j + 1][1]):
                tempo = sub_li[j]
                sub_li[j]= sub_li[j + 1]
                sub_li[j + 1]= tempo
    return sub_li

def Sort_1(sub_li):
    l = len(sub_li)
    for i in range(0, l):
        for j in range(0, l-i-1):
            if (sub_li[j][0] > sub_li[j + 1][0]):
                tempo = sub_li[j]
                sub_li[j]= sub_li[j + 1]
                sub_li[j + 1]= tempo
    return sub_li
  
# Driver Code
sub_li =[['rishav', 10], ['akash', 5], ['ram', 20], ['gaurav', 15]]
#print(len(Sort_2(location_circles)))

# %%
location_circles = Sort_2(location_circles)
print(location_circles)
# Out:
# [[878, 22], [402, 24], [674, 24], [468, 26], [334, 26], [252, 28], [806, 28], [946, 28], [530, 30], [58, 30], [738, 30], [122, 32], [602, 32], [188, 34], [876, 68], [800, 74], [468, 76], [402, 76], [266, 76], [674, 78], [536, 78], [734, 80], [942, 82], [122, 84], [190, 84], [324, 86], [50, 88], [596, 88], [696, 114], [944, 118], [872, 120], [806, 126], [672, 128], [330, 128], [398, 130], [730, 130], [468, 130], [198, 130], [262, 132], [536, 132], [56, 136], [124, 136], [600, 138], [878, 168], [806, 174], [536, 174], [334, 180], [400, 180], [196, 180], [604, 180], [666, 182], [932, 182], [862, 182], [60, 184], [740, 184], [262, 184], [466, 184], [124, 188], [872, 222], [740, 222], [942, 224], [262, 224], [668, 224], [186, 228], [402, 228], [470, 228], [336, 228], [812, 230], [124, 238], [56, 238], [608, 258], [822, 258], [682, 268], [256, 270], [462, 270], [538, 270], [182, 272], [394, 272], [750, 274], [324, 274], [944, 276], [878, 278], [808, 284], [60, 284], [128, 288], [180, 314], [818, 316], [946, 326], [126, 328], [58, 328], [878, 332], [182, 334], [542, 356], [390, 356], [616, 358], [466, 358], [698, 358], [308, 360], [180, 366], [950, 374], [822, 378], [876, 378], [58, 382], [124, 390], [548, 412], [694, 412], [390, 414], [460, 414], [616, 416], [308, 418], [186, 426], [952, 426], [876, 428], [824, 430], [124, 434], [54, 444], [624, 470], [386, 472], [696, 474], [312, 476], [184, 480], [944, 480], [876, 482], [826, 484], [56, 494], [122, 496], [952, 528], [824, 528], [616, 528], [694, 528], [886, 532], [386, 534], [310, 534], [540, 536], [464, 536], [120, 538], [180, 542], [946, 584], [548, 586], [124, 586], [822, 586], [178, 588], [392, 588], [308, 588], [622, 590], [698, 592], [464, 592], [882, 594], [52, 598], [958, 636], [56, 640], [126, 642], [616, 644], [830, 644], [884, 646], [394, 646], [540, 646], [308, 646], [700, 648], [180, 650], [464, 650], [884, 692], [116, 692], [50, 694], [830, 700], [180, 704], [886, 740], [958, 740], [470, 742], [58, 744], [612, 746], [124, 748], [250, 748], [690, 750], [758, 750], [392, 752], [324, 756], [832, 756], [180, 760], [540, 760], [678, 790], [894, 794], [192, 794], [958, 794], [332, 794], [124, 794], [746, 796], [820, 796], [400, 796], [614, 796], [474, 796], [58, 798], [680, 840], [192, 846], [124, 846], [958, 846], [884, 848], [614, 848], [746, 850], [824, 850], [468, 852], [54, 852], [538, 852], [266, 852], [332, 854], [400, 854], [122, 896], [472, 896], [614, 896], [892, 898], [822, 900], [960, 900], [56, 902], [682, 904], [326, 904], [266, 904], [748, 904], [536, 904], [402, 904], [190, 908], [876, 916], [120, 950], [682, 952], [958, 954], [892, 954], [538, 954], [754, 956], [404, 956], [608, 958], [54, 958], [194, 960], [262, 960], [470, 960], [822, 960], [334, 964]]

# %%
old_height = location_circles[0][1]
grids = []
row = []
min_height = location_circles[0][1]
max_height = location_circles[-1][1]
gap = (max_height-min_height)*0.05

for i in range(len(location_circles)):
        height = location_circles[i][1]
        print(height-old_height, gap)
        if (height-old_height) < (gap*1.05):
            row.append(location_circles[i])
        else:
            row = Sort_2(row)
            space = get_space(row)
            row = check_row(row, space)
            grids.append(row)
            row = []
            row.append(location_circles[i])
            
            old_height = height
        if i == (len(location_circles)-1):
            # row = Sort_1(row)
            # space = get_space(row)
            # row = check_row(row, space)
            # grids.append(row)
            # row = []
            # row.append(location_circles[i])
            # old_height = height
            break
for row in grids:
    print(row)
    print()

# print(grids)
# print(len(grids))
# Out:
# 0 47.1
# 2 47.1
# 2 47.1
# 4 47.1
# 4 47.1
# 6 47.1
# 6 47.1
# 6 47.1
# 8 47.1
# 8 47.1
# 8 47.1
# 10 47.1
# 10 47.1
# 12 47.1
# 46 47.1
# 52 47.1
# 2 47.1
# 2 47.1
# 2 47.1
# 4 47.1
# 4 47.1
# 6 47.1
# 8 47.1
# 10 47.1
# 10 47.1
# 12 47.1
# 14 47.1
# 14 47.1
# 40 47.1
# 44 47.1
# 46 47.1
# 52 47.1
# 2 47.1
# 2 47.1
# 4 47.1
# 4 47.1
# 4 47.1
# 4 47.1
# 6 47.1
# 6 47.1
# 10 47.1
# 10 47.1
# 12 47.1
# 42 47.1
# 48 47.1
# 48 47.1
# 54 47.1
# 0 47.1
# 0 47.1
# 0 47.1
# 2 47.1
# 2 47.1
# 2 47.1
# 4 47.1
# 4 47.1
# 4 47.1
# 4 47.1
# 8 47.1
# 42 47.1
# 42 47.1
# 44 47.1
# 44 47.1
# 44 47.1
# 48 47.1
# 48 47.1
# 48 47.1
# 48 47.1
# 50 47.1
# 8 47.1
# 8 47.1
# 28 47.1
# 28 47.1
# 38 47.1
# 40 47.1
# 40 47.1
# 40 47.1
# 42 47.1
# 42 47.1
# 44 47.1
# 44 47.1
# 46 47.1
# 48 47.1
# 54 47.1
# 0 47.1
# 4 47.1
# 30 47.1
# 32 47.1
# 42 47.1
# 44 47.1
# 44 47.1
# 48 47.1
# 50 47.1
# 22 47.1
# 22 47.1
# 24 47.1
# 24 47.1
# 24 47.1
# 26 47.1
# 32 47.1
# 40 47.1
# 44 47.1
# 44 47.1
# 48 47.1
# 56 47.1
# 22 47.1
# 22 47.1
# 24 47.1
# 24 47.1
# 26 47.1
# 28 47.1
# 36 47.1
# 36 47.1
# 38 47.1
# 40 47.1
# 44 47.1
# 54 47.1
# 26 47.1
# 28 47.1
# 30 47.1
# 32 47.1
# 36 47.1
# 36 47.1
# 38 47.1
# 40 47.1
# 50 47.1
# 2 47.1
# 34 47.1
# 34 47.1
# 34 47.1
# 34 47.1
# 38 47.1
# 40 47.1
# 40 47.1
# 42 47.1
# 42 47.1
# 44 47.1
# 48 47.1
# 90 47.1
# 2 47.1
# 2 47.1
# 2 47.1
# 4 47.1
# 4 47.1
# 4 47.1
# 6 47.1
# 8 47.1
# 8 47.1
# 10 47.1
# 14 47.1
# 52 47.1
# 4 47.1
# 6 47.1
# 8 47.1
# 8 47.1
# 10 47.1
# 10 47.1
# 10 47.1
# 10 47.1
# 12 47.1
# 14 47.1
# 14 47.1
# 56 47.1
# 0 47.1
# 2 47.1
# 8 47.1
# 12 47.1
# 48 47.1
# 48 47.1
# 50 47.1
# 2 47.1
# 4 47.1
# 6 47.1
# 6 47.1
# 8 47.1
# 8 47.1
# 10 47.1
# 14 47.1
# 14 47.1
# 18 47.1
# 18 47.1
# 48 47.1
# 52 47.1
# 0 47.1
# 0 47.1
# 0 47.1
# 0 47.1
# 2 47.1
# 2 47.1
# 2 47.1
# 2 47.1
# 2 47.1
# 4 47.1
# 46 47.1
# 52 47.1
# 0 47.1
# 0 47.1
# 2 47.1
# 2 47.1
# 4 47.1
# 4 47.1
# 6 47.1
# 6 47.1
# 6 47.1
# 6 47.1
# 8 47.1
# 8 47.1
# 50 47.1
# 0 47.1
# 0 47.1
# 2 47.1
# 4 47.1
# 4 47.1
# 6 47.1
# 8 47.1
# 8 47.1
# 8 47.1
# 8 47.1
# 8 47.1
# 8 47.1
# 12 47.1
# 20 47.1
# 54 47.1
# 2 47.1
# 4 47.1
# 4 47.1
# 4 47.1
# 6 47.1
# 6 47.1
# 8 47.1
# 8 47.1
# 10 47.1
# 10 47.1
# 10 47.1
# 10 47.1
# 14 47.1
# [[878, 22], [1644.3000000000002, 22], [402, 24], [674, 24], [1430.1000000000001, 24], [468, 26], [1213.8, 26], [334, 26], [1073.1000000000001, 26], [252, 28], [806, 28], [946, 28], [1715.7, 28], [530, 30], [1278.9, 30], [58, 30], [738, 30], [122, 32], [602, 32], [188, 34], [876, 68]]
#
# [[800, 74], [468, 76], [402, 76], [266, 76], [674, 78], [536, 78], [734, 80], [942, 82], [122, 84], [190, 84], [324, 86], [50, 88], [596, 88], [696, 114], [944, 118], [872, 120]]
#
# [[806, 126], [672, 128], [330, 128], [398, 130], [730, 130], [468, 130], [198, 130], [262, 132], [536, 132], [56, 136], [124, 136], [600, 138], [878, 168], [806, 174], [536, 174]]
#
# [[334, 180], [400, 180], [196, 180], [604, 180], [666, 182], [932, 182], [862, 182], [60, 184], [740, 184], [262, 184], [466, 184], [124, 188], [872, 222], [740, 222], [942, 224], [262, 224], [668, 224], [186, 228], [402, 228], [470, 228], [336, 228]]
#
# [[812, 230], [124, 238], [56, 238], [608, 258], [822, 258], [682, 268], [256, 270], [462, 270], [538, 270], [182, 272], [394, 272], [750, 274], [324, 274], [944, 276], [878, 278]]
#
# [[808, 284], [1709.4, 284], [60, 284], [128, 288], [180, 314], [818, 316], [946, 326], [1854.3000000000002, 326], [126, 328], [993.3000000000001, 328], [58, 328], [878, 332]]
#
# [[182, 334], [542, 356], [390, 356], [616, 358], [466, 358], [698, 358], [308, 360], [180, 366], [950, 374], [822, 378], [876, 378], [58, 382]]
#
# [[124, 390], [548, 412], [694, 412], [390, 414], [460, 414], [616, 416], [308, 418], [186, 426], [952, 426], [876, 428], [824, 430], [124, 434]]
#
# [[54, 444], [624, 470], [386, 472], [696, 474], [312, 476], [184, 480], [944, 480], [876, 482], [826, 484]]
#
# [[56, 494], [122, 496], [191.1, 496], [263.65500000000003, 496], [339.83775, 496], [419.82963750000005, 496], [503.8211193750001, 496], [592.0121753437501, 496], [684.6127841109376, 496], [781.8434233164845, 496], [883.9355944823088, 496], [952, 528], [1062.6000000000001, 528], [824, 528], [616, 528], [694, 528], [886, 532], [386, 534], [310, 534], [540, 536], [464, 536], [120, 538], [180, 542]]
#
# [[946, 584], [548, 586], [124, 586], [822, 586], [178, 588], [392, 588], [308, 588], [622, 590], [698, 592], [464, 592], [882, 594], [52, 598]]
#
# [[958, 636], [1304.1000000000001, 636], [56, 640], [126, 642], [430.5, 642], [616, 644], [830, 644], [884, 646], [1226.4, 646], [394, 646], [540, 646], [865.2, 646], [308, 646], [700, 648], [180, 650], [464, 650]]
#
# [[884, 692], [1003.8000000000001, 692], [116, 692], [197.4, 692], [50, 694], [128.1, 694], [210.105, 694], [296.21025000000003, 694], [830, 700], [180, 704], [886, 740], [958, 740]]
#
# [[470, 742], [638.4, 742], [58, 744], [205.8, 744], [360.99, 744], [523.9395000000001, 744], [612, 746], [787.5, 746], [124, 748], [250, 748], [407.40000000000003, 748], [572.6700000000001, 748], [690, 750], [758, 750], [392, 752], [324, 756], [832, 756], [180, 760], [540, 760], [678, 790]]
#
# [[894, 794], [1591.8, 794], [192, 794], [958, 794], [1659.0, 794], [332, 794], [1001.7, 794], [124, 794], [746, 796], [820, 796], [1514.1000000000001, 796], [400, 796], [614, 796], [474, 796], [58, 798], [680, 840]]
#
# [[192, 846], [273.0, 846], [124, 846], [201.60000000000002, 846], [283.08000000000004, 846], [368.63400000000007, 846], [458.4657000000001, 846], [552.7889850000001, 846], [651.8284342500002, 846], [755.8198559625002, 846], [865.0108487606253, 846], [958, 846], [1077.3, 846], [884, 848], [614, 848], [746, 850], [824, 850], [468, 852], [54, 852], [538, 852], [266, 852], [332, 854], [400, 854]]
#
# [[122, 896], [472, 896], [614, 896], [892, 898], [1656.9, 898], [822, 900], [960, 900], [1728.3000000000002, 900], [56, 902], [682, 904], [1436.4, 904], [326, 904], [1062.6000000000001, 904], [266, 904], [748, 904], [1505.7, 904], [536, 904], [402, 904], [190, 908], [876, 916]]
# C:\Users\HP\AppData\Local\Temp\ipykernel_14164\2438683756.py:6: RuntimeWarning: overflow encountered in ushort_scalars
#   distance = row[i+1][0] - row[i][0]

# %%
def get_space(row):
    distances = []
    for i in range(len(row)):
        if i == (len(row)-1):
            break
        distance = row[i+1][0] - row[i][0]
        distances.append(distance)
    min(distances)
    return distance

# %%
def check_row(row, space):
    for i in range(len(row)):
        if i == (len(row)-1):
            break
        #print("row[i+1][0]-row[i][0]", row[i+1][0]-row[i][0])
        if row[i+1][0]-row[i][0] > (space*1.7):
            new_point = [(row[i][0]+space)*1.05, row[i][1]]
            row.insert(i+1, new_point)
    return row

# %%
length = len(grids[0])
for row in grids:
    print(len(row))
    
print(grids)
# Out:
# 21
# 16
# 15
# 21
# 15
# 12
# 12
# 12
# 9
# 23
# 12
# 16
# 12
# 20
# 16
# 23
# 20
# [[[878, 22], [1644.3000000000002, 22], [402, 24], [674, 24], [1430.1000000000001, 24], [468, 26], [1213.8, 26], [334, 26], [1073.1000000000001, 26], [252, 28], [806, 28], [946, 28], [1715.7, 28], [530, 30], [1278.9, 30], [58, 30], [738, 30], [122, 32], [602, 32], [188, 34], [876, 68]], [[800, 74], [468, 76], [402, 76], [266, 76], [674, 78], [536, 78], [734, 80], [942, 82], [122, 84], [190, 84], [324, 86], [50, 88], [596, 88], [696, 114], [944, 118], [872, 120]], [[806, 126], [672, 128], [330, 128], [398, 130], [730, 130], [468, 130], [198, 130], [262, 132], [536, 132], [56, 136], [124, 136], [600, 138], [878, 168], [806, 174], [536, 174]], [[334, 180], [400, 180], [196, 180], [604, 180], [666, 182], [932, 182], [862, 182], [60, 184], [740, 184], [262, 184], [466, 184], [124, 188], [872, 222], [740, 222], [942, 224], [262, 224], [668, 224], [186, 228], [402, 228], [470, 228], [336, 228]], [[812, 230], [124, 238], [56, 238], [608, 258], [822, 258], [682, 268], [256, 270], [462, 270], [538, 270], [182, 272], [394, 272], [750, 274], [324, 274], [944, 276], [878, 278]], [[808, 284], [1709.4, 284], [60, 284], [128, 288], [180, 314], [818, 316], [946, 326], [1854.3000000000002, 326], [126, 328], [993.3000000000001, 328], [58, 328], [878, 332]], [[182, 334], [542, 356], [390, 356], [616, 358], [466, 358], [698, 358], [308, 360], [180, 366], [950, 374], [822, 378], [876, 378], [58, 382]], [[124, 390], [548, 412], [694, 412], [390, 414], [460, 414], [616, 416], [308, 418], [186, 426], [952, 426], [876, 428], [824, 430], [124, 434]], [[54, 444], [624, 470], [386, 472], [696, 474], [312, 476], [184, 480], [944, 480], [876, 482], [826, 484]], [[56, 494], [122, 496], [191.1, 496], [263.65500000000003, 496], [339.83775, 496], [419.82963750000005, 496], [503.8211193750001, 496], [592.0121753437501, 496], [684.6127841109376, 496], [781.8434233164845, 496], [883.9355944823088, 496], [952, 528], [1062.6000000000001, 528], [824, 528], [616, 528], [694, 528], [886, 532], [386, 534], [310, 534], [540, 536], [464, 536], [120, 538], [180, 542]], [[946, 584], [548, 586], [124, 586], [822, 586], [178, 588], [392, 588], [308, 588], [622, 590], [698, 592], [464, 592], [882, 594], [52, 598]], [[958, 636], [1304.1000000000001, 636], [56, 640], [126, 642], [430.5, 642], [616, 644], [830, 644], [884, 646], [1226.4, 646], [394, 646], [540, 646], [865.2, 646], [308, 646], [700, 648], [180, 650], [464, 650]], [[884, 692], [1003.8000000000001, 692], [116, 692], [197.4, 692], [50, 694], [128.1, 694], [210.105, 694], [296.21025000000003, 694], [830, 700], [180, 704], [886, 740], [958, 740]], [[470, 742], [638.4, 742], [58, 744], [205.8, 744], [360.99, 744], [523.9395000000001, 744], [612, 746], [787.5, 746], [124, 748], [250, 748], [407.40000000000003, 748], [572.6700000000001, 748], [690, 750], [758, 750], [392, 752], [324, 756], [832, 756], [180, 760], [540, 760], [678, 790]], [[894, 794], [1591.8, 794], [192, 794], [958, 794], [1659.0, 794], [332, 794], [1001.7, 794], [124, 794], [746, 796], [820, 796], [1514.1000000000001, 796], [400, 796], [614, 796], [474, 796], [58, 798], [680, 840]], [[192, 846], [273.0, 846], [124, 846], [201.60000000000002, 846], [283.08000000000004, 846], [368.63400000000007, 846], [458.4657000000001, 846], [552.7889850000001, 846], [651.8284342500002, 846], [755.8198559625002, 846], [865.0108487606253, 846], [958, 846], [1077.3, 846], [884, 848], [614, 848], [746, 850], [824, 850], [468, 852], [54, 852], [538, 852], [266, 852], [332, 854], [400, 854]], [[122, 896], [472, 896], [614, 896], [892, 898], [1656.9, 898], [822, 900], [960, 900], [1728.3000000000002, 900], [56, 902], [682, 904], [1436.4, 904], [326, 904], [1062.6000000000001, 904], [266, 904], [748, 904], [1505.7, 904], [536, 904], [402, 904], [190, 908], [876, 916]]]

# %%
print(len(grids), len(grids[0]))
# Out:
# 14 21

# %%
plt.imshow(imS)
plt.show()
print(len(imS))
print(len(imS[0]))
# Out:
# 540
# 960

# %%
def closest(colors,color):
    colors = np.array(colors)
    color = np.array(color)    
    distances = np.sqrt(np.sum((colors-color)**2,axis=1))    
    index_of_smallest = np.where(distances==np.amin(distances))
    smallest_distance = colors[index_of_smallest]
    return smallest_distance

# %%
import webcolors
from collections import Counter
def get_avarege_color(point, im):
    
    colors = []
    colors_name =[]
    list_of_colors = [[0,0,255],[0,0,0],[255,255,255],[0,255,0],[255,0,0],[255,255,0]]
    for i in range(5):
        for z in range(5):
            color = im[round(point[1]+i), round(point[0]+z)]
            colors.append(color)
            color = im[round(point[1]-i), round(point[0]-z)]
            colors.append(color)
    
    for i in range(len(colors)):         
        closest_color = closest(list_of_colors,colors[i])        
        colors_name.append(webcolors.rgb_to_name((closest_color[0][0],  closest_color[0][1],  closest_color[0][2])))
    data = Counter(colors_name)    
    return data.most_common(1)[0][0]

# %%
import numpy as np
import webcolors

color_name_grid = []

for row in grids:    
    color_name_row = []
    for point in row:        
        color = get_avarege_color(point, im)        
        color_name_row.append(color)        
    color_name_grid.append(color_name_row)

for i in range(len(color_name_grid)):
    print(color_name_grid[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [28], line 9
#       7 color_name_row = []
#       8 for point in row:
# ----> 9     color = get_avarege_color(point, im)
#      10     color_name_row.append(color)
#      11 color_name_grid.append(color_name_row)
#
# Cell In [26], line 10, in get_avarege_color(point, im)
#       8 for i in range(5):
#       9     for z in range(5):
# ---> 10         color = im[round(point[1]+i), round(point[0]+z)]
#      11         colors.append(color)
#      12         color = im[round(point[1]-i), round(point[0]-z)]
#
# IndexError: index 1060 is out of bounds for axis 1 with size 1000

# %%
import numpy as np
def get_similarity(picture_grid, plan_grid):
    row_pic= len(picture_grid)
    column_pic = len(picture_grid[0])

    row_plan = len(plan_grid)
    column_plan = len(plan_grid[0])

    row_diff = row_pic - row_plan +1
    column_diff = column_pic  - column_plan +1

    
    comp_list = []
    
    for row_comp in range(row_diff):
        for column_comp in range(column_diff):
            number_of_same_colors = 0

            for i in range(len(plan_grid)):
                for z in range(len(plan_grid[0])):
                    plan_color = plan_grid[i][z]
                    pic_color = picture_grid[i+row_comp][z+column_comp]
                    if plan_color == pic_color:
                        number_of_same_colors +=1
            
            comp_list.append(number_of_same_colors)
    max_index = np.argmax(comp_list)
    max_similarity = comp_list[max_index]
    total_pixel = len(plan_grid) * len(plan_grid[0])
    similarity = (max_similarity/total_pixel)*100
    return similarity

# %%
similarity = get_similarity(color_name_grid, color_name_grid)
print(similarity)
# Out:
# 100.0
